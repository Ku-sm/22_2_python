# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
dataset = pd.read_csv(r'Life_expectancy.csv',sep=',')

# %%
dataset
# Out:
#           Country  Year      Status  Life expectancy  Adult mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# ...

# %%
dataset.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult mortality',
#        'Infant deaths', 'Alcohol', 'Percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'Under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', 'HIV/AIDS', 'GDP', 'Population', 'Thinness 1-19 years',
#        'Thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
data = dataset[['Life expectancy', 'Adult mortality',
       'Infant deaths', 'Alcohol', 'Percentage expenditure', 'Hepatitis B',
       'Measles', 'BMI', 'Under-five deaths ', 'Polio', 'Total expenditure',
       'Diphtheria ', 'HIV/AIDS', 'GDP', 'Population', 'Thinness 1-19 years',
       'Thinness 5-9 years', 'Income composition of resources', 'Schooling']]

# %%
data
# Out:
#       Life expectancy  Adult mortality  Infant deaths  Alcohol  \
# 0                65.0            263.0             62     0.01
# 1                59.9            271.0             64     0.01
# 2                59.9            268.0             66     0.01
# 3                59.5            272.0             69     0.01
# 4                59.2            275.0             71     0.01
# ...               ...              ...            ...      ...
# 2933             44.3            723.0             27     4.36
# 2934             44.5            715.0             26     4.06
# 2935             44.8             73.0             25     4.43
# 2936             45.3            686.0             25     1.72
# 2937             46.0            665.0             24     1.68
#
#       Percentage expenditure  Hepatitis B  Measles   BMI  Under-five deaths   \
# 0                  71.279624         65.0     1154  19.1                  83
# ...

# %%
data.fillna(value = 0)
# Out:
#       Life expectancy  Adult mortality  Infant deaths  Alcohol  \
# 0                65.0            263.0             62     0.01
# 1                59.9            271.0             64     0.01
# 2                59.9            268.0             66     0.01
# 3                59.5            272.0             69     0.01
# 4                59.2            275.0             71     0.01
# ...               ...              ...            ...      ...
# 2933             44.3            723.0             27     4.36
# 2934             44.5            715.0             26     4.06
# 2935             44.8             73.0             25     4.43
# 2936             45.3            686.0             25     1.72
# 2937             46.0            665.0             24     1.68
#
#       Percentage expenditure  Hepatitis B  Measles   BMI  Under-five deaths   \
# 0                  71.279624         65.0     1154  19.1                  83
# ...

# %%
dataset['Status'].unique()
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %%
# 명목 데이터의 값 호출 가능
np.unique(dataset['Status'],return_counts=True)
# Out:
# (array(['Developed', 'Developing'], dtype=object),
#  array([ 512, 2426], dtype=int64))

# %%
table = dataset.describe()
table
# Out:
#               Year  Life expectancy  Adult mortality  Infant deaths  \
# count  2938.000000      2928.000000      2928.000000    2938.000000
# mean   2007.518720        69.224932       164.796448      30.303948
# std       4.613841         9.523867       124.292079     117.926501
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2004.000000        63.100000        74.000000       0.000000
# 50%    2008.000000        72.100000       144.000000       3.000000
# 75%    2012.000000        75.700000       228.000000      22.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            Alcohol  Percentage expenditure  Hepatitis B        Measles  \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
np.mean(dataset['Alcohol'])
# Out:
# 4.602860787172012

# %%
mean_val=table.loc['mean']

# %% [markdown]
# 정규화 방법 2가지

# %% [markdown]
# $$ x_{1}^{new} = \frac{x_{1}-min(x_{1})}{max(x_{1})-min(x_{1})}$$

# %% [markdown]
# $$ x_{1}^{new} = \frac{x_{1}-mean(x_{1})}{std(x_{1})} , std = \sigma^2_{x_1}$$

# %%
# 데이터를 히스토그램으로 표현
dataset['Infant deaths'].hist()
# Out:
# <AxesSubplot:>

# %%
dataset['Year'].hist(bins=16)
# Out:
# <AxesSubplot:>

# %%
#bins는 도수계급개수, figzise는 그림의 크기
dataset['Life expectancy'].hist(bins=30,figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
dataset.loc[25:100]
# Out:
#      Country  Year      Status  Life expectancy  Adult mortality  \
# 25   Albania  2006  Developing             74.2             99.0
# 26   Albania  2005  Developing             73.5             15.0
# 27   Albania  2004  Developing             73.0             17.0
# 28   Albania  2003  Developing             72.8             18.0
# 29   Albania  2002  Developing             73.3             15.0
# ..       ...   ...         ...              ...              ...
# 96   Armenia  2015  Developing             74.8            118.0
# 97   Armenia  2014  Developing             74.6             12.0
# 98   Armenia  2013  Developing             74.4            123.0
# 99   Armenia  2012  Developing             74.4            121.0
# 100  Armenia  2011  Developing             73.9            128.0
#
#      Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 25               1     5.31                3.302154         98.0       68
# ...

# %%
dataset.iloc[25:100,:10]
# Out:
#       Country  Year      Status  Life expectancy  Adult mortality  \
# 25    Albania  2006  Developing             74.2             99.0
# 26    Albania  2005  Developing             73.5             15.0
# 27    Albania  2004  Developing             73.0             17.0
# 28    Albania  2003  Developing             72.8             18.0
# 29    Albania  2002  Developing             73.3             15.0
# ..        ...   ...         ...              ...              ...
# 95  Argentina  2000  Developing             74.1            137.0
# 96    Armenia  2015  Developing             74.8            118.0
# 97    Armenia  2014  Developing             74.6             12.0
# 98    Armenia  2013  Developing             74.4            123.0
# 99    Armenia  2012  Developing             74.4            121.0
#
#     Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles
# 25              1     5.31                3.302154         98.0       68
# ...

# %% [markdown]
# 1) 인구 천만 이상
# 2) 기대 수명이 60이하인 나라

# %%
condition1 = dataset['Life expectancy'] <=60

# %%
condition2 = dataset['Population'] <= 10000000

# %%
# 연산 기호로 해야 다중 계산이 된다.
condition1 & condition2
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 2933    False
# 2934    False
# 2935     True
# 2936    False
# 2937    False
# Length: 2938, dtype: bool

# %%
index = dataset[condition1 & condition2]

# %%
index['Country'].unique()
# Out:
# array(['Afghanistan', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Central African Republic',
#        'Chad', 'Comoros', 'Djibouti', 'Equatorial Guinea', 'Eritrea',
#        'Ethiopia', 'Gabon', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Kenya', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Mali',
#        'Mauritania', 'Mozambique', 'Namibia', 'Niger', 'Nigeria',
#        'Papua New Guinea', 'Rwanda', 'Senegal', 'Sierra Leone',
#        'South Africa', 'South Sudan', 'Sudan', 'Swaziland', 'Timor-Leste',
#        'Togo', 'Uganda', 'Zambia', 'Zimbabwe'], dtype=object)

# %%
indices = np.array(range(2938))
indice1 = indices[condition1 & condition2]

dataset.loc[indice1]
# Out:
#           Country  Year      Status  Life expectancy  Adult mortality  \
# 1     Afghanistan  2014  Developing             59.9            271.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# 5     Afghanistan  2010  Developing             58.8            279.0
# 6     Afghanistan  2009  Developing             58.6            281.0
# ...           ...   ...         ...              ...              ...
# 2927     Zimbabwe  2010  Developing             52.4            527.0
# 2928     Zimbabwe  2009  Developing             50.0            587.0
# 2930     Zimbabwe  2007  Developing             46.6             67.0
# 2932     Zimbabwe  2005  Developing             44.6            717.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# ...

# %% [markdown]
# 결측치 찾기

# %%
dataset
# Out:
#           Country  Year      Status  Life expectancy  Adult mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult mortality                  2928 non-null   float64
#  5   Infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   Percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  Under-five deaths                2938 non-null   int64
# ...

# %%
dataset.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult mortality                     10
# Infant deaths                        0
# Alcohol                            194
# Percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# Under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# Thinness 1-19 years                 34
# Thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# 데이터 손실이 발생한다.

# %%
dataset.dropna(axis=1,how='any').shape
# Out:
# (2938, 8)

# %%
dataset.dropna(axis=0,how='any').shape
# Out:
# (1649, 22)

# %%
indices = np.array(dataset.index)

# %%
# 관측치별로 값이 1개라도 없으면 True가 나온다
null_data = indices[dataset.isnull().any(axis=1)]

# %%
Missing_data = dataset.loc[null_data]

# %%
Missing_data
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 32     Algeria  2015  Developing             75.6             19.0
# 44     Algeria  2003  Developing             71.7            146.0
# 45     Algeria  2002  Developing             71.6            145.0
# 46     Algeria  2001  Developing             71.4            145.0
# 47     Algeria  2000  Developing             71.3            145.0
# ...        ...   ...         ...              ...              ...
# 2918    Zambia  2003  Developing             46.4             64.0
# 2919    Zambia  2002  Developing             45.5             69.0
# 2920    Zambia  2001  Developing             44.6            611.0
# 2921    Zambia  2000  Developing             43.8            614.0
# 2922  Zimbabwe  2015  Developing             67.0            336.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 32               21      NaN                0.000000         95.0       63
# ...

# %%
Missing_data.isna().sum(axis=1).mean()
# Out:
# 1.9883630721489527

# %%
mena_H = table.loc[['Hepatitis B']]
Missing_data.loc['Hepatitis B'].fillna(value = mean_H)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [139], in <cell line: 1>()
# ----> 1 mena_H = table.loc[['Hepatitis B']]
#       2 Missing_data.loc['Hepatitis B'].fillna(value = mean_H)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1301, in _LocIndexer._getitem_axis(self, key, axis)
#    1298     if hasattr(key, "ndim") and key.ndim > 1:
#    1299         raise ValueError("Cannot index with multidimensional key")
# -> 1301     return self._getitem_iterable(key, axis=axis)
#    1303 # nested tuple slicing
#    1304 if is_nested_tuple(key, labels):
#
# ...

# %%
MD1 = Missing_data.fillna(method='bfill')
MD2 = MD1.fillna(method='ffill')
MD2
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 32     Algeria  2015  Developing             75.6             19.0
# 44     Algeria  2003  Developing             71.7            146.0
# 45     Algeria  2002  Developing             71.6            145.0
# 46     Algeria  2001  Developing             71.4            145.0
# 47     Algeria  2000  Developing             71.3            145.0
# ...        ...   ...         ...              ...              ...
# 2918    Zambia  2003  Developing             46.4             64.0
# 2919    Zambia  2002  Developing             45.5             69.0
# 2920    Zambia  2001  Developing             44.6            611.0
# 2921    Zambia  2000  Developing             43.8            614.0
# 2922  Zimbabwe  2015  Developing             67.0            336.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 32               21     0.34                0.000000         95.0       63
# ...

# %%
import missingno as msno

# %%
msno.bar(dataset)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### -----------------------------------------------------------------------------------------------
